# %%
"jupytext_formats: ipynb,py"
import simulate

# %% [markdown]
# # Simulations with STDP and STD (NE = NI = 50     K = 5)

# %%
simulate.runsim()

# %%
simulate.display_sim_results()

# %% [markdown]
# # STDP tests

# %% [markdown]
# ### One postsynaptic neuron firing at regular intervals receiving input from all other neurons

# %%
import sim_lif_tests

# %%
sim_lif_tests.run_stdp_test()

# %% [markdown]
# ## STDP with symmetric kernel

# %%
import sim_lif_tests
sim_lif_tests.run_stdp_test(stdp_lr_post=-0.013) # setting negative post learning rate should give a symmetric kernel

# %% [markdown]
# ### Network with symmetric kernel

# %%
import simulate
simulate.runsim(t_stop=11000.0, stdp_lr_post=-0.013, stdp_tau_pre=20.0, stp_A=1.0)

# %%
simulate.runsim(t_stop=11000.0, stdp_lr_post=-0.013, stdp_tau_pre=20.0, stp_A=0.0001)

# %%
simulate.runsim(t_stop=11000.0, stdp_lr_post=-0.013, stdp_tau_pre=20.0, stp_A=5.0)

# %%
simulate.compare_stdp_on_vs_off(t_stop=10000.0)

# %%
simulate.compare_stdp_on_vs_off(t_stop=1000.0, NE=1000, NI = 1000, K=100, v_ext=0.012)

# %%
simulate.display_sim_results() # display latest sim results i.e STDP-STP ON

# %%
simulate.runsim(v_ext=0.054)

# %%
simulate.compare_stdp_on_vs_off(v_ext=0.038, NE=100, NI=100, K=10)

# %%
simulate.compare_stdp_on_vs_off(v_ext=0.053, NE=50, NI=50, K=5)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, t_stop=12000.0, stdp_lr_post=-0.013)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, stp_A=0.01, t_stop=12000.0, stdp_lr_post=-0.013)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, stp_A=0.1, t_stop=12000.0, stdp_lr_post=-0.013)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, stp_A=0.1, t_stop=12000.0, stdp_lr_post=-0.013)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, t_stop=12000.0, STDP_ON=0, STP_ON=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a73cac552166> in <module>
# ----> 1 simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, t_stop=12000.0, STDP_ON=0, STP_ON=1)
#
# ~/Documents/lab/code/lif/simulate.py in runsim(**params)
#      35     update_sim_param(**params)
#      36     stdp.simu()
# ---> 37     display_sim_results()
#      38
#      39     #
#
# ~/Documents/lab/code/lif/simulate.py in display_sim_results()
#     151     plt.figure()
#     152     plt.gcf().set_size_inches(10, 4.8)
# --> 153     plt.plot(t, aw)
#     154     plt.ylabel('stdp weights')
#     155     plt.xlabel('Time (s)')
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# ...

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, stp_A=0.1, t_stop=10000.0, stdp_lr_post=-0.013, stdp_lr_pre=0.04)

# %%
simulate.runsim(v_ext=0.038, NE=100, NI=100, K=10, stp_A=0.1, t_stop=10000.0, stdp_lr_post=0.1)

# %%
import simulate

# %%
simulate.runsim(stp_A=1.0, stp_U=1.0, IF_ISN=1, NE=2, NI=0, K=1, v_ext=0.118, STP_ON=1, STDP_ON=0, t_stop=600.0,  discard_time=0.0)

# %%
simulate.runsim(stp_A=1.0, stp_U=0.6, IF_ISN=1, NE=50, NI=50, K=5, v_ext=0.118, STP_ON=1, STDP_ON=0, t_stop=600.0,  discard_time=0.0)

# %%
simulate.runsim(stp_A=1.0, stp_U=1.0, IF_ISN=1, NE=100, NI=100, K=5, v_ext=0.118, STP_ON=1, STDP_ON=1, stdp_lr_post=-0.013, t_stop=20000.0)

# %% [markdown]
# # $\tau_{STDP \pm} = 100ms$

# %%
simulate.runsim(stp_A=1.0, stp_U=1.0, IF_ISN=1, NE=100, NI=100, K=5, v_ext=0.118, STP_ON=1, STDP_ON=1, stdp_tau_pre=100.0, stdp_tau_post=100.0, stdp_lr_post=-0.013, t_stop=20000.0)

# %%
import simulate

# %%
simulate.runsim(stp_A=1.0, stp_U=1.0, IF_ISN=1, NE=100, NI=100, K=5, v_ext=0.118, STP_ON=1, STDP_ON=0, t_stop=20000.0)

# %%
simulate.runsim(stp_A=1.0, stp_U=.75, IF_ISN=1, NE=100, NI=100, K=5, v_ext=0.118, STP_ON=1, STDP_ON=1, stdp_tau_pre=40.0, stdp_tau_post=40.0, stdp_lr_post=-0.013, t_stop=20000.0)

# %%
import simulate

# %%
simulate.runsim(stp_A=1.0, stp_U=0.44, IF_ISN=1, v_ext=0.118, stdp_tau_pre=20.0, stdp_tau_post=20.0, t_stop=12000.0)

# %%
simulate.runsim(stp_A=1.0, stp_U=0.44, stdp_tau_f=20, IF_ISN=1, v_ext=0.118, t_stop=12000.0)

# %%
simulate.runsim(NE=1000, NI=1000, K=100, STDP_ON=0, STP_ON=1, IF_ISN=0, v_ext=0.018, t_stop=2000.0)

# %%
simulate.runsim(NE=1000, NI=1000, K=100, STDP_ON=0, STP_ON=1, ISN=1, v_ext=0.118, t_stop=2000.0)

# %%
import simulate

# %%
simulate.runsim(NE=10000, NI=10000, K=1000, STDP_ON=0, STP_ON=0, ISN=1, v_ext=0.01, t_stop=200.0)

# %% [markdown]
# # Bump

# %%
import simulate

# %%
simulate.runsim(t_stop=1000.,STP_ON=0, STDP_ON=0, v_ext=0.016, NE=1000, NI=1000, K=100)
# Out:
# Mean field rates:
# r_E = 5.666666666666668
# r_I = 13.222222222222221

# %%
simulate.runsim(t_stop=4000., IS_RANDOM=1, alpha=0., STP_ON=0, STDP_ON=0, v_ext=0.008, NE=1000, NI=1000, K=100)

# %%
simulate.runsim(t_stop=1000., IS_RANDOM=0, alpha=0., STP_ON=0, STDP_ON=0, v_ext=0.012, NE=4000, NI=4000, K=800)

# %%
import simulate

# %%
simulate.runsim(STP_ON=0, STDP_ON=0, IS_RANDOM=0, alpha=6., K=500, NE=5000, NI=5000, t_stop=2000.0, v_ext=0.005)
# Out:
# loading spikes
# done
# Mean field rates:
# r_E = 9.895833333333336
# r_I = 12.256944444444446

# %%
simulate.runsim(STP_ON=1, stp_A=1.0, stp_U=.04, STDP_ON=0, IS_RANDOM=0, alpha=6., K=500, NE=5000, NI=5000, t_stop=2000.0, v_ext=0.005)
# Out:
# loading spikes
# done
# Mean field rates:
# r_E = 9.895833333333336
# r_I = 12.256944444444446

# %%
simulate.runsim(STP_ON=0, stp_A=1.0, stp_U=1., STDP_ON=0, IS_RANDOM=0, alpha=6., K=500, NE=5000, NI=5000, t_stop=2000.0, v_ext=0.005)
# Out:
# loading spikes
# done
# Mean field rates:
# r_E = 9.895833333333336
# r_I = 12.256944444444446

# %%
simulate.runsim_paramfile('src/params_mato.cfg')
# Out:
# loading spikes
# done
# NOT IN BALANCED REGIME!:
# JE0/JI0 > JE/JI must be True
# JE0/JI0 = 2.0
# JE/JI = 2.840909090909091
# Mean field rates:
# r_E = 7.098765432098765
# r_I = 45.37037037037037

# %%
import simulate

# %%
simulate.runsim(STDP_ON=1, STP_ON=0, IS_RANDOM=1, K=50, NE=500, NI=500, t_stop=5000.0, discard_time=100.0, v_ext=0.008)
# Out:
# loading spikes
# done
# loading weights
# done
# Mean field rates:
# r_E = 23.333333333333336
# r_I = 27.77777777777778

# %%
simulate.call_rbm_analysis()
# Out:
# Directory  /Users/shrisha/Documents/lab/code/rbm_analysis/data/model/alphas  already exists
# Directory  /Users/shrisha/Documents/lab/code/rbm_analysis/data/model/tuning_curves  already exists
# Directory  /Users/shrisha/Documents/lab/code/rbm_analysis/figures/model/sce  already exists
# Directory  /Users/shrisha/Documents/lab/code/rbm_analysis/figures/model/summary  already exists
# #neurons = 484
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f8fe00af930f> in <module>
# ----> 1 simulate.call_rbm_analysis()
#
# ~/Documents/lab/code/lif/simulate.py in call_rbm_analysis()
#     189     rbm_analysis_ARGS = set_rbm_analysis_ARGS()
#     190     ad.setup_folders(dataset='model')
# --> 191     ad.main(rbm_analysis_ARGS)
#     192
#     193
#
# ~/Documents/lab/code/rbm_analysis/analyse_dataset.py in main(ARGS)
# ...

# %%
import sim_lif_tests

# %%
sim_lif_tests.run_stdp_test()
# Out:
# Best fit parameters: t0=-0.9999265483245148, w0=0.4953878414781532, wp=0.25881668567983, wn=0.22084377354622875, tau=23.727003374258384

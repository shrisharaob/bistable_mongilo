# %%
"jupytext_formats: ipynb,py"
import sys 
sys.path.append("../")
import simulate

# %%
simulate.runsim_paramfile('../src/params_brunel.cfg')
# Out:
# loading spikes
# done
# ../simulate.py:316: UserWarning: loadtxt: Empty input file: "data/spikes.txt"
#   st = np.loadtxt('data/spikes.txt')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-322fed6b6b38> in <module>
# ----> 1 simulate.runsim_paramfile('../src/params_brunel.cfg')
#
# ~/Documents/lab/code/lif/simulate.py in runsim_paramfile(paramfile)
#     120     stdp.simu()
#     121
# --> 122     display_sim_results(conf)
#     123
#     124     if (int(conf['scaling_type']) == 0):
#
# ~/Documents/lab/code/lif/simulate.py in display_sim_results(params)
#     323     ax2 = fig.add_subplot(gs[1, 2])
#     324
# --> 325     pu.plot_raster(st, ax=ax0)
#     326     # if int(params["IS_RANDOM"]):
#     327     #     pu.plot_raster(st)
#
# ~/Documents/lab/code/rbm_analysis/helpers/plot_utils.py in plot_raster(data, color, neuron_idx_offset, NE, ax)
#     251
# ...

# %%
simulate.runsim_brunel(v_ext=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-738fd6db930b> in <module>
# ----> 1 simulate.runsim_brunel(v_ext=0.01)
#
# NameError: name 'simulate' is not defined

# %%
simulate.runsim_brunel(v_ext=0.0, g_brunel=.0)
# Out:
# loading spikes
# done
# ../simulate.py:316: UserWarning: loadtxt: Empty input file: "data/spikes.txt"
#   st = np.loadtxt('data/spikes.txt')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-198edff784d4> in <module>
# ----> 1 simulate.runsim_brunel(v_ext=0.0, g_brunel=.0)
#
# ~/Documents/lab/code/lif/simulate.py in runsim_brunel(**params)
#      69
#      70     # display the simulation results
# ---> 71     display_sim_results(new_conf)
#      72
#      73
#
# ~/Documents/lab/code/lif/simulate.py in display_sim_results(params)
#     323     ax2 = fig.add_subplot(gs[1, 2])
#     324
# --> 325     pu.plot_raster(st, ax=ax0)
#     326     # if int(params["IS_RANDOM"]):
#     327     #     pu.plot_raster(st)
#
# ~/Documents/lab/code/rbm_analysis/helpers/plot_utils.py in plot_raster(data, color, neuron_idx_offset, NE, ax)
#     251
#     252     if NE is None:
# ...

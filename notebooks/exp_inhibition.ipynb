# %%
"jupytext_formats: ipynb,py"
import sys
import numpy as np
import ipdb  # noqa
import seaborn
sys.path.append('./src/build/lib.macosx-10.7-x86_64-3.7')
seaborn.set()
from simulate import runsim  # noqa
#, update_sim_param, display_sim_results, check_balance_conditions, mean_field_rates, restore_default_params  # noqa

# %% [markdown]
# ####

# %%
def sim_loop_ove_Jei(t_stop=1000.0):
    # Jei_list = np.arange(-0.5, -2.6, -0.5)
    Jei_list = np.arange(-2.5, -1.4, 0.5)
    for Jei in Jei_list:
        print(f'Jei = {Jei}')
        runsim(Jei=Jei,
               STDP_ON=0,
               STP_ON=0,
               t_stop=t_stop,
               discard_time=100.0,
               NE=1000,
               NI=1000,
               K=100,
               v_ext=0.0052)

# %%
sim_loop_ove_Jei()
# Out:
# Jei = -2.5
# loading spikes
# done
# NOT IN BALANCED REGIME!:
# JE0/JI0 > JE/JI must be True
# JE0/JI0 = 2.0
# JE/JI = 2.2727272727272725
# Mean field rates:
# r_E = 2.2698412698412698
# r_I = 5.158730158730159
# Jei = -2.0
# loading spikes
# done
# Mean field rates:
# r_E = 5.135802469135803
# r_I = 8.024691358024691
# Jei = -1.5
# loading spikes
# done
# Mean field rates:
# r_E = 15.166666666666668
# r_I = 18.055555555555557

# %%
import simulate

# %% [markdown]
# ## Square wave FF input

# %%
simulate.runsim(STDP_ON=0, STP_ON=0, t_stop=1000.0, discard_time=100.0)
# Out:
# 1000.0
# loading spikes
# done
# NOT IN BALANCED REGIME!:
# JE0/JI0 > JE/JI must be True
# JE0/JI0 = 1.0
# JE/JI = 1.5
# NOT IN BALANCED REGIME!:
# JE0/JI0 > 1 must be True
# JE0/JI0 = 1.0
# Mean field rates:
# r_E = 3.541666666666668
# r_I = 9.444444444444446

# %%
import simulate

# %%
simulate.runsim(STDP_ON=0, STP_ON=0, t_stop=1000.0, discard_time=100.0, v_ext=0.0125)
# Out:
# 1000.0
# loading spikes
# done
# NOT IN BALANCED REGIME!:
# JE0/JI0 > JE/JI must be True
# JE0/JI0 = 1.0
# JE/JI = 1.5
# NOT IN BALANCED REGIME!:
# JE0/JI0 > 1 must be True
# JE0/JI0 = 1.0
# Mean field rates:
# r_E = 3.541666666666668
# r_I = 9.444444444444446
